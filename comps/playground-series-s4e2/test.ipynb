# %%
import pandas as pd
import numpy as np
train = pd.read_csv("./playground-series-s4e2/train.csv")
train.head()
# Out:
#    id  Gender        Age    Height      Weight family_history_with_overweight  \
# 0   0    Male  24.443011  1.699998   81.669950                            yes
# 1   1  Female  18.000000  1.560000   57.000000                            yes
# 2   2  Female  18.000000  1.711460   50.165754                            yes
# 3   3  Female  20.952737  1.710730  131.274851                            yes
# 4   4    Male  31.641081  1.914186   93.798055                            yes
#
#   FAVC      FCVC       NCP        CAEC SMOKE      CH2O SCC       FAF  \
# 0  yes  2.000000  2.983297   Sometimes    no  2.763573  no  0.000000
# 1  yes  2.000000  3.000000  Frequently    no  2.000000  no  1.000000
# 2  yes  1.880534  1.411685   Sometimes    no  1.910378  no  0.866045
# 3  yes  3.000000  3.000000   Sometimes    no  1.674061  no  1.467863
# 4  yes  2.679664  1.971472   Sometimes    no  1.979848  no  1.967973
#
#         TUE       CALC                 MTRANS           NObeyesdad
# ...

# %%
pd.options.display.float_format = '{:,.2f}'.format
def summary(df):
    print(f'data shape: {df.shape}')
    summ = pd.DataFrame(df.dtypes, columns=['data type'])
    summ['#missing'] = df.isnull().sum().values 
    summ['%missing'] = df.isnull().sum().values / len(df) * 100
    summ['#unique'] = df.nunique().values
    desc = pd.DataFrame(df.describe(include='all').transpose())
    summ['min'] = desc['min'].values
    summ['max'] = desc['max'].values
    summ['average'] = desc['mean'].values
    summ['standard_deviation'] = desc['std'].values
    summ['first value'] = df.loc[0].values
    summ['second value'] = df.loc[1].values
    summ['third value'] = df.loc[2].values
    
    return summ

summary(train)
# Out:
# data shape: (20758, 26)
#                                    data type  #missing  %missing  #unique  \
# id                                     int64         0      0.00    20758
# Age                                  float64         0      0.00     1703
# Height                               float64         0      0.00     1833
# Weight                               float64         0      0.00     1979
# FCVC                                 float64         0      0.00      934
# NCP                                  float64         0      0.00      689
# CH2O                                 float64         0      0.00     1506
# FAF                                  float64         0      0.00     1360
# TUE                                  float64         0      0.00     1297
# Gender_Female                          int32         0      0.00        2
# family_history_with_overweight_yes     int32         0      0.00        2
# ...

# %%
train_d = pd.get_dummies(train.drop(columns=["NObeyesdad"]), dtype=int)
train_d.columns
train_d.drop(columns=["Gender_Male", "family_history_with_overweight_no", "FAVC_no", "SMOKE_no", "SCC_no", "id"], inplace=True)
train_d.head()
train_ids = train['id']
train_target = train['NObeyesdad']
train_target
# Out:
# 0        Overweight_Level_II
# 1              Normal_Weight
# 2        Insufficient_Weight
# 3           Obesity_Type_III
# 4        Overweight_Level_II
#                 ...
# 20753        Obesity_Type_II
# 20754    Insufficient_Weight
# 20755        Obesity_Type_II
# 20756    Overweight_Level_II
# 20757        Obesity_Type_II
# Name: NObeyesdad, Length: 20758, dtype: object
