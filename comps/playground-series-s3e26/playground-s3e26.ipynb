# %% [markdown]
# ## Em Colbert

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn.metrics import log_loss
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score, RepeatedStratifiedKFold, cross_val_predict
from sklearn.ensemble import RandomForestClassifier
from numba import jit

# %%
TRAIN = pd.read_csv("./playground-series-s3e26/train.csv")
TEST = pd.read_csv("./playground-series-s3e26/test.csv")
SAMPLE_SUB = pd.read_csv("./playground-series-s3e26/sample_submission.csv")

train = TRAIN.copy()
test = TEST.copy()
submission = SAMPLE_SUB.copy()
train_id = train.id
train_status = train.Status
test_id = test.id

train.drop(columns=['id', 'Status'], inplace=True)
test.drop(columns=['id'], inplace=True)

test.head()
# Out:
#    N_Days             Drug    Age Sex Ascites Hepatomegaly Spiders Edema  \
# 0    3839  D-penicillamine  19724   F       N            Y       N     N
# 1    2468  D-penicillamine  14975   F       N            N       N     N
# 2      51          Placebo  13149   F       N            Y       N     Y
# 3    2330  D-penicillamine  20510   F       N            N       N     N
# 4    1615  D-penicillamine  21904   F       N            Y       N     N
#
#    Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  Tryglicerides  \
# 0        1.2        546.0     3.37    65.0    1636.0  151.90           90.0
# 1        1.1        660.0     4.22    94.0    1257.0  151.90          155.0
# 2        2.0        151.0     2.96    46.0     961.0   69.75          101.0
# 3        0.6        293.0     3.85    40.0     554.0  125.55           56.0
# 4        1.4        277.0     2.97   121.0    1110.0  125.00          126.0
#
#    Platelets  Prothrombin  Stage
# 0      430.0         10.6    2.0
# 1      227.0         10.0    2.0
# 2      213.0         13.0    4.0
# 3      270.0         10.6    2.0
# 4      221.0          9.8    1.0

# %%
pd.options.display.float_format = '{:,.2f}'.format
def summary(df):
    print(f'data shape: {df.shape}')
    summ = pd.DataFrame(df.dtypes, columns=['data type'])
    summ['#missing'] = df.isnull().sum().values
    summ['%missing'] = df.isnull().sum().values / len(df) * 100
    summ['#unique'] = df.nunique().values
    desc = pd.DataFrame(df.describe(include='all').transpose())
    summ['min'] = desc['min'].values
    summ['max'] = desc['max'].values
    summ['average'] = desc['mean'].values
    summ['standard_deviation'] = desc['std'].values
    summ['first value'] = df.loc[0].values
    summ['second value'] = df.loc[1].values
    summ['third value'] = df.loc[2].values

    return summ

summary(test)
# Out:
# data shape: (5271, 18)
#               data type  #missing  %missing  #unique      min       max  \
# N_Days            int64         0      0.00      409    41.00  4,795.00
# Drug             object         0      0.00        2      NaN       NaN
# Age               int64         0      0.00      363 9,598.00 28,650.00
# Sex              object         0      0.00        2      NaN       NaN
# Ascites          object         0      0.00        2      NaN       NaN
# Hepatomegaly     object         0      0.00        2      NaN       NaN
# Spiders          object         0      0.00        2      NaN       NaN
# Edema            object         0      0.00        3      NaN       NaN
# Bilirubin       float64         0      0.00      108     0.30     28.00
# Cholesterol     float64         0      0.00      222   120.00  1,775.00
# Albumin         float64         0      0.00      154     1.96      4.64
# Copper          float64         0      0.00      164     4.00    588.00
# Alk_Phos        float64         0      0.00      362   289.00 13,862.40
# SGOT            float64         0      0.00      195    26.35    457.25
# Tryglicerides   float64         0      0.00      155    33.00    598.00
# Platelets       float64         0      0.00      223    62.00    563.00
# Prothrombin     float64         0      0.00       47     9.00     15.20
# Stage           float64         0      0.00        4     1.00      4.00
#
#                 average standard_deviation      first value     second value  \
# N_Days         2,038.70           1,086.84             3839             2468
# Drug                NaN                NaN  D-penicillamine  D-penicillamine
# Age           18,497.76           3,583.90            19724            14975
# Sex                 NaN                NaN                F                F
# Ascites             NaN                NaN                N                N
# Hepatomegaly        NaN                NaN                Y                N
# Spiders             NaN                NaN                N                N
# Edema               NaN                NaN                N                N
# Bilirubin          2.60               3.85             1.20             1.10
# Cholesterol      352.49             200.44           546.00           660.00
# Albumin            3.54               0.35             3.37             4.22
# Copper            84.70              77.54            65.00            94.00
# Alk_Phos       1,811.23           1,935.35         1,636.00         1,257.00
# SGOT             113.59              48.96           151.90           151.90
# Tryglicerides    115.29              52.60            90.00           155.00
# Platelets        264.02              87.58           430.00           227.00
# Prothrombin       10.63               0.79            10.60            10.00
# Stage              3.04               0.86             2.00             2.00
#
#               third value
# N_Days                 51
# Drug              Placebo
# Age                 13149
# Sex                     F
# Ascites                 N
# Hepatomegaly            Y
# Spiders                 N
# Edema                   Y
# Bilirubin            2.00
# Cholesterol        151.00
# Albumin              2.96
# Copper              46.00
# Alk_Phos           961.00
# SGOT                69.75
# Tryglicerides      101.00
# Platelets          213.00
# Prothrombin         13.00
# Stage                4.00

# %% [markdown]
# Observations
#
# - Every type of each object is in both train and test
#
# - You'll need to give a predicted percent for each status

# %% [markdown]
# ## Data Cleaning 1

# %%
train_d, test_d = pd.get_dummies(train, dtype=int), pd.get_dummies(test, dtype=int)

ss = StandardScaler()
train_dn = pd.DataFrame(ss.fit_transform(train_d), columns=train_d.columns)
test_dn = pd.DataFrame(ss.transform(test_d), columns=test_d.columns)

test_dn.head()
# Out:
#    N_Days   Age  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos  SGOT  \
# 0    1.65  0.37      -0.37         1.00    -0.52   -0.25     -0.09  0.76
# 1    0.40 -0.92      -0.39         1.58     1.94    0.13     -0.29  0.76
# 2   -1.81 -1.42      -0.16        -1.02    -1.70   -0.50     -0.45 -0.92
# 3    0.27  0.58      -0.52        -0.29     0.87   -0.58     -0.66  0.22
# 4   -0.38  0.96      -0.31        -0.38    -1.67    0.49     -0.37  0.21
#
#    Tryglicerides  Platelets  ...  Sex_M  Ascites_N  Ascites_Y  Hepatomegaly_N  \
# 0          -0.48       1.88  ...  -0.28       0.22      -0.22           -0.98
# 1           0.76      -0.44  ...  -0.28       0.22      -0.22            1.02
# 2          -0.27      -0.60  ...  -0.28       0.22      -0.22           -0.98
# 3          -1.13       0.05  ...  -0.28       0.22      -0.22            1.02
# 4           0.20      -0.51  ...  -0.28       0.22      -0.22           -0.98
#
#    Hepatomegaly_Y  Spiders_N  Spiders_Y  Edema_N  Edema_S  Edema_Y
# 0            0.98       0.57      -0.57     0.32    -0.23    -0.21
# 1           -1.02       0.57      -0.57     0.32    -0.23    -0.21
# 2            0.98       0.57      -0.57    -3.10    -0.23     4.68
# 3           -1.02       0.57      -0.57     0.32    -0.23    -0.21
# 4            0.98       0.57      -0.57     0.32    -0.23    -0.21
#
# [5 rows x 25 columns]

# %%
Y = train_status.map({"C":0, "CL":1, "D":2})
Y
# Out:
# 0       2
# 1       0
# 2       2
# 3       0
# 4       0
#        ..
# 7900    0
# 7901    0
# 7902    2
# 7903    2
# 7904    0
# Name: Status, Length: 7905, dtype: int64

# %%
rf = RandomForestClassifier(criterion='log_loss')
kfold = RepeatedStratifiedKFold(n_splits=10, n_repeats=1)

rfcvs = cross_val_score(rf, train_dn, Y, scoring='neg_log_loss', cv=kfold, n_jobs=-1)

rf.fit(train_dn, Y)
# Out:
# RandomForestClassifier(criterion='log_loss')

# %%
-1*rfcvs.mean()
# Out:
# 0.5428967490777389

# %%
preds = rf.predict_proba(test_dn)
preds
# Out:
# array([[0.66, 0.03, 0.31],
#        [0.71, 0.16, 0.13],
#        [0.08, 0.03, 0.89],
#        ...,
#        [0.94, 0.04, 0.02],
#        [0.99, 0.  , 0.01],
#        [0.43, 0.06, 0.51]])

# %%
sub_1 = SAMPLE_SUB.copy()

# %%
preds_1 = pd.DataFrame(preds, columns=["C", "CL", "D"])
sub_1.Status_C = preds_1.C
sub_1.Status_CL = preds_1.CL
sub_1.Status_D = preds_1.D

# %%
sub_1.to_csv("./submissions/submission1.csv", index=False)

# %%
def mil():
    a=0
    for i in range(100000000):
        a += i

@jit(nopython=True)
def fast():
    a=0
    for i in range(100000000):
        a += i
